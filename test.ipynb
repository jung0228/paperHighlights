# %%
key = "AIzaSyCG4ME4qos5V2Q5bVw7xS21WCmFt8RB8ZU"

# %%
# single_turn.py
import google.generativeai as genai
import os
genai.configure(api_key=os.getenv(key))

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "./Authentication.json"
# os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = credential_path
response = model.generate_content("인공지능에 대해 한 문장으로 설명하세요.")
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[9], line 3
#       1 os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "./Authentication.json"
#       2 # os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = credential_path
# ----> 3 response = model.generate_content("인공지능에 대해 한 문장으로 설명하세요.")
#
# File ~/opt/anaconda3/envs/papermage/lib/python3.11/site-packages/google/generativeai/generative_models.py:241, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, **kwargs)
#     234 request = self._prepare_request(
#     235     contents=contents,
#     236     generation_config=generation_config,
#     237     safety_settings=safety_settings,
#     238     **kwargs,
#     239 )
#     240 if self._client is None:
# --> 241     self._client = client.get_default_generative_client()
#     243 if stream:
#     244     with generation_types.rewrite_stream_error():
#
# File ~/opt/anaconda3/envs/papermage/lib/python3.11/site-packages/google/generativeai/client.py:230, in get_default_generative_client()
#     229 def get_default_generative_client() -> glm.GenerativeServiceClient:
# --> 230     return _client_manager.get_default_client("generative")
#
# File ~/opt/anaconda3/envs/papermage/lib/python3.11/site-packages/google/generativeai/client.py:161, in _ClientManager.get_default_client(self, name)
#     159 client = self.clients.get(name)
#     160 if client is None:
# --> 161     client = self.make_client(name)
#     162     self.clients[name] = client
#     163 return client
#
# File ~/opt/anaconda3/envs/papermage/lib/python3.11/site-packages/google/generativeai/client.py:121, in _ClientManager.make_client(self, name)
#     118 if not self.client_config:
#     119     configure()
# --> 121 client = cls(**self.client_config)
#     123 if not self.default_metadata:
#     124     return client
#
# File ~/opt/anaconda3/envs/papermage/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:433, in GenerativeServiceClient.__init__(self, credentials, transport, client_options, client_info)
#     428     credentials = google.auth._default.get_api_key_credentials(
#     429         api_key_value
#     430     )
#     432 Transport = type(self).get_transport_class(transport)
# --> 433 self._transport = Transport(
#     434     credentials=credentials,
#     435     credentials_file=client_options.credentials_file,
#     436     host=api_endpoint,
#     437     scopes=client_options.scopes,
#     438     client_cert_source_for_mtls=client_cert_source_func,
#     439     quota_project_id=client_options.quota_project_id,
#     440     client_info=client_info,
#     441     always_use_jwt_access=True,
#     442     api_audience=client_options.api_audience,
#     443 )
#
# File ~/opt/anaconda3/envs/papermage/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/grpc.py:150, in GenerativeServiceGrpcTransport.__init__(self, host, credentials, credentials_file, scopes, channel, api_mtls_endpoint, client_cert_source, ssl_channel_credentials, client_cert_source_for_mtls, quota_project_id, client_info, always_use_jwt_access, api_audience)
#     145             self._ssl_channel_credentials = grpc.ssl_channel_credentials(
#     146                 certificate_chain=cert, private_key=key
#     147             )
#     149 # The base transport sets the host, credentials and scopes
# --> 150 super().__init__(
#     151     host=host,
#     152     credentials=credentials,
#     153     credentials_file=credentials_file,
#     154     scopes=scopes,
#     155     quota_project_id=quota_project_id,
#     156     client_info=client_info,
#     157     always_use_jwt_access=always_use_jwt_access,
#     158     api_audience=api_audience,
#     159 )
#     161 if not self._grpc_channel:
#     162     self._grpc_channel = type(self).create_channel(
#     163         self._host,
#     164         # use the credentials which are saved
#    (...)
#     175         ],
#     176     )
#
# File ~/opt/anaconda3/envs/papermage/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/base.py:98, in GenerativeServiceTransport.__init__(self, host, credentials, credentials_file, scopes, quota_project_id, client_info, always_use_jwt_access, api_audience, **kwargs)
#      94     credentials, _ = google.auth.load_credentials_from_file(
#      95         credentials_file, **scopes_kwargs, quota_project_id=quota_project_id
#      96     )
#      97 elif credentials is None:
# ---> 98     credentials, _ = google.auth.default(
#      99         **scopes_kwargs, quota_project_id=quota_project_id
#     100     )
#     101     # Don't apply audience if the credentials file passed from user.
#     102     if hasattr(credentials, "with_gdch_audience"):
#
# File ~/opt/anaconda3/envs/papermage/lib/python3.11/site-packages/google/auth/_default.py:657, in default(scopes, request, quota_project_id, default_scopes)
#     645 checkers = (
#     646     # Avoid passing scopes here to prevent passing scopes to user credentials.
#     647     # with_scopes_if_required() below will ensure scopes/default scopes are
#    (...)
#     653     lambda: _get_gce_credentials(request, quota_project_id=quota_project_id),
#     654 )
#     656 for checker in checkers:
# --> 657     credentials, project_id = checker()
#     658     if credentials is not None:
#     659         credentials = with_scopes_if_required(
#     660             credentials, scopes, default_scopes=default_scopes
#     661         )
#
# File ~/opt/anaconda3/envs/papermage/lib/python3.11/site-packages/google/auth/_default.py:650, in default.<locals>.<lambda>()
#     639 from google.auth.credentials import CredentialsWithQuotaProject
#     641 explicit_project_id = os.environ.get(
#     642     environment_vars.PROJECT, os.environ.get(environment_vars.LEGACY_PROJECT)
#     643 )
#     645 checkers = (
#     646     # Avoid passing scopes here to prevent passing scopes to user credentials.
#     647     # with_scopes_if_required() below will ensure scopes/default scopes are
#     648     # safely set on the returned credentials since requires_scopes will
#     649     # guard against setting scopes on user credentials.
# --> 650     lambda: _get_explicit_environ_credentials(quota_project_id=quota_project_id),
#     651     lambda: _get_gcloud_sdk_credentials(quota_project_id=quota_project_id),
#     652     _get_gae_credentials,
#     653     lambda: _get_gce_credentials(request, quota_project_id=quota_project_id),
#     654 )
#     656 for checker in checkers:
#     657     credentials, project_id = checker()
#
# File ~/opt/anaconda3/envs/papermage/lib/python3.11/site-packages/google/auth/_default.py:270, in _get_explicit_environ_credentials(quota_project_id)
#     267     return _get_gcloud_sdk_credentials(quota_project_id=quota_project_id)
#     269 if explicit_file is not None:
# --> 270     credentials, project_id = load_credentials_from_file(
#     271         os.environ[environment_vars.CREDENTIALS], quota_project_id=quota_project_id
#     272     )
#     274     return credentials, project_id
#     276 else:
#
# File ~/opt/anaconda3/envs/papermage/lib/python3.11/site-packages/google/auth/_default.py:114, in load_credentials_from_file(filename, scopes, default_scopes, quota_project_id, request)
#      82 """Loads Google credentials from a file.
#      83
#      84 The credentials file must be a service account key, stored authorized
#    (...)
#     111         wrong format or is missing.
#     112 """
#     113 if not os.path.exists(filename):
# --> 114     raise exceptions.DefaultCredentialsError(
#     115         "File {} was not found.".format(filename)
#     116     )
#     118 with io.open(filename, "r") as file_obj:
#     119     try:
#
# DefaultCredentialsError: File ./Authentication.json was not found.

# %%
print(response.text)
